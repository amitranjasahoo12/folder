# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("Book1.xlsx")

# %%
df.head()
# Out:
#      Name  a     b     c      cd  avg_rss12  var_rss12  avg_rss13  var_rss13  \
# 0    Name  2  23.0  22.0     0.0      23.75       0.43      24.00       0.00
# 1  sukesh  3  45.0  23.0   250.0      22.67       0.94      24.00       0.00
# 2   badal  4  56.0  43.0   500.0      21.33       0.47      24.00       0.00
# 3  naresh  5  76.0  32.0   750.0        NaN       0.00      24.00       0.00
# 4    sily  6  87.0  12.0  1000.0      23.00       0.71      23.75       0.43
#
#    avg_rss23  var_rss23 target
# 0      24.67       0.47    NaN
# 1      24.67       0.94   flag
# 2      24.75       0.83    NaN
# 3      25.25       1.09    NaN
# 4      24.75       0.83    NaN

# %%
df.isnull().sum()
# Out:
# Name          0
# a             0
# b             5
# c             0
# cd            1
# avg_rss12     1
# var_rss12     0
# avg_rss13     0
# var_rss13     3
# avg_rss23     0
# var_rss23     3
# target       14
# dtype: int64

# %%
df.replace(np.nan,"")
# Out:
#       Name     a     b      c      cd avg_rss12  var_rss12  avg_rss13  \
# 0     Name     2  23.0  22.00     0.0     23.75       0.43      24.00
# 1   sukesh     3  45.0  23.00   250.0     22.67       0.94      24.00
# 2    badal     4  56.0  43.00   500.0     21.33       0.47      24.00
# 3   naresh     5  76.0  32.00   750.0                 0.00      24.00
# 4     sily     6  87.0  12.00  1000.0      23.0       0.71      23.75
# 5     babi    78  98.0  45.00  1250.0     24.33       0.47      24.00
# 6     baby     9  23.0  56.00  1500.0     23.75       1.09      24.25
# 7     Name  1750         0.43    24.0       0.0      24.75       0.43
# 8   sukesh  2000         0.43    24.5       0.5      25.75       0.83
# 9    badal  2250         0.71   24.25      0.43      25.75       1.30
# 10  naresh  2500         0.87   24.25      0.43      25.00       1.00
# 11    sily  2750         1.30   24.75      0.43      25.00       1.00
# ...

# %%
df["target"].fillna("sili", inplace=True)

# %%
df
# Out:
#       Name     a     b      c       cd  avg_rss12  var_rss12  avg_rss13  \
# 0     Name     2  23.0  22.00     0.00      23.75       0.43      24.00
# 1   sukesh     3  45.0  23.00   250.00      22.67       0.94      24.00
# 2    badal     4  56.0  43.00   500.00      21.33       0.47      24.00
# 3   naresh     5  76.0  32.00   750.00        NaN       0.00      24.00
# 4     sily     6  87.0  12.00  1000.00      23.00       0.71      23.75
# 5     babi    78  98.0  45.00  1250.00      24.33       0.47      24.00
# 6     baby     9  23.0  56.00  1500.00      23.75       1.09      24.25
# 7     Name  1750   NaN   0.43    24.00       0.00      24.75       0.43
# 8   sukesh  2000   NaN   0.43    24.50       0.50      25.75       0.83
# 9    badal  2250   NaN   0.71    24.25       0.43      25.75       1.30
# 10  naresh  2500   NaN   0.87    24.25       0.43      25.00       1.00
# 11    sily  2750   NaN   1.30    24.75       0.43      25.00       1.00
# ...

# %%
df.isnull().sum()
# Out:
# Name         0
# a            0
# b            5
# c            0
# cd           1
# avg_rss12    1
# var_rss12    0
# avg_rss13    0
# var_rss13    3
# avg_rss23    0
# var_rss23    3
# target       0
# dtype: int64
